# %%
# !pip install mediapipe
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.21-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (3.10.0)
# Collecting numpy<2 (from mediapipe)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mediapipe) (4.11.0.86)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Downloading protobuf-4.25.7-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Downloading mediapipe-0.10.21-cp311-cp311-manylinux_2_28_x86_64.whl (35.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 14.7 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 40.1 MB/s eta 0:00:00
# Downloading protobuf-4.25.7-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 14.9 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Installing collected packages: protobuf, numpy, sounddevice, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.7 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.7 which is incompatible.
# Successfully installed mediapipe-0.10.21 numpy-1.26.4 protobuf-4.25.7 sounddevice-0.5.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Running cells with 'Python 3.10.11' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/ACER/AppData/Local/Microsoft/WindowsApps/python3.10.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Found 3984 images belonging to 26 classes.
# Found 1886 images belonging to 26 classes.

# %% [markdown]
# ## Import

# %%
import os
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import backend
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 import os
# ----> 2 import tensorflow as tf
#       4 from tensorflow import keras
#       5 from tensorflow.keras import layers
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %% [markdown]
# ## Hyperparameters

# %%
# Hyperparameters
learning_rate = 0.002           # Laju pembelajaran untuk optimizer
label_smoothing_factor = 0.1
batch_size = 64                   # Jumlah sampel per batch saat training
num_epochs = 30                   # Jumlah iterasi penuh melalui dataset
num_classes = 26                 # Output kelas: A-Z (26 huruf)
# Values are from table 4.
patch_size = 4  # 2x2, for the Transformer blocks.
image_size = 256  # Ukuran input image untuk MobileViT
expansion_factor = 2  # expansion factor for the MobileNetV2 blocks.

# %% [markdown]
# ## MobileViT utilities
#
# The MobileViT architecture is comprised of the following blocks:
#
# * Strided 3x3 convolutions that process the input image.
# * [MobileNetV2](https://arxiv.org/abs/1801.04381)-style inverted residual blocks for
# downsampling the resolution of the intermediate feature maps.
# * MobileViT blocks that combine the benefits of Transformers and convolutions. It is
# presented in the figure below (taken from the
# [original paper](https://arxiv.org/abs/2110.02178)):
#
#
# ![](https://i.imgur.com/mANnhI7.png)

# %%
def conv_block(x, filters=16, kernel_size=3, strides=2):
    """
    Mendefinisikan blok konvolusi dasar yang terdiri dari layer Conv2D dengan aktivasi Swish.

    Args:
        x: Tensor input ke blok konvolusi (biasanya output dari layer sebelumnya).
        filters: Jumlah filter konvolusi. Default 16.
        kernel_size: Ukuran kernel (filter) konvolusi (misal: 3 untuk 3x3). Default 3.
        strides: Langkah pergerakan kernel di atas input. Strides > 1 melakukan downsampling. Default 2.

    Returns:
        Tensor output setelah operasi konvolusi dan aktivasi.
    """
    # Membuat instance dari layer Konvolusi 2D
    conv_layer = layers.Conv2D(
        filters=filters,        # Jumlah filter
        kernel_size=kernel_size,# Ukuran kernel
        strides=strides,        # Langkah pergerakan kernel (downsampling jika > 1)
        activation=keras.activations.swish, # Fungsi aktivasi Swish (non-linear)
        padding="same",         # Padding untuk mempertahankan ukuran spasial (relatif terhadap stride)
    )
    # Menerapkan layer konvolusi ke tensor input 'x' dan mengembalikan hasilnya
    return conv_layer(x)

# Reference: https://github.com/keras-team/keras/blob/e3858739d178fe16a0c77ce7fab88b0be6dbbdc7/keras/applications/imagenet_utils.py#L413C17-L435

# Fungsi ini digunakan untuk menghitung padding yang benar, terutama saat melakukan downsampling
# dengan stride > 1, untuk memastikan dimensi output cocok dengan ekspektasi.
# Referensi implementasi berasal dari utilitas aplikasi Keras.
def correct_pad(inputs, kernel_size):
    """
    Menghitung tuple padding yang benar untuk operasi konvolusi/pooling.
    Digunakan untuk menangani dimensi spasial ganjil saat downsampling.

    Args:
        inputs: Tensor input yang akan diberi padding. Digunakan untuk mendapatkan ukuran spasialnya.
        kernel_size: Ukuran kernel (filter) atau jendela pooling. Dapat berupa integer atau tuple (tinggi, lebar).

    Returns:
        Tuple of tuples yang merepresentasikan padding yang perlu ditambahkan ke input.
        Format: ((padding_atas, padding_bawah), (padding_kiri, padding_kanan)).
    """
    # Menentukan indeks dimensi spasial (tinggi dan lebar) berdasarkan format data gambar.
    # Jika 'channels_first' (misal: (batch, channels, height, width)), dimensi spasial dimulai dari indeks 2.
    # Jika 'channels_last' (misal: (batch, height, width, channels)), dimensi spasial dimulai dari indeks 1.
    img_dim = 2 if backend.image_data_format() == "channels_first" else 1

    # Mendapatkan ukuran spasial input tensor (tinggi, lebar).
    # Slicing [img_dim : (img_dim + 2)] akan mengambil dimensi tinggi dan lebar.
    input_size = inputs.shape[img_dim : (img_dim + 2)]

    # Memastikan kernel_size adalah tuple (tinggi_kernel, lebar_kernel).
    # Jika diberikan sebagai integer tunggal, ubah menjadi tuple (integer, integer).
    if isinstance(kernel_size, int):
        kernel_size = (kernel_size, kernel_size)

    # Menghitung "penyesuaian" padding yang diperlukan jika dimensi input ganjil.
    # adjust[0] = 1 jika tinggi input ganjil, 0 jika genap.
    # adjust[1] = 1 jika lebar input ganjil, 0 jika genap.
    if input_size[0] is None:
        # Menangani kasus di mana dimensi input tidak diketahui pada waktu kompilasi (misal, None).
        # Asumsikan penyesuaian 1,1 (paling aman untuk downsampling pada dimensi ganjil).
        adjust = (1, 1)
    else:
        # Hitung sisa pembagian dengan 2. 1 - (dim % 2) akan menjadi 1 jika dim ganjil, dan 0 jika dim genap.
        adjust = (1 - input_size[0] % 2, 1 - input_size[1] % 2)

    # Menghitung padding "benar" teoritis tanpa mempertimbangkan dimensi ganjil.
    # Untuk ukuran kernel K, padding yang umum adalah K // 2 (integer division).
    # Ini akan memberikan padding simetris jika input berukuran tepat untuk stride.
    correct = (kernel_size[0] // 2, kernel_size[1] // 2)

    # Mengembalikan tuple padding untuk diterapkan pada layer ZeroPadding2D.
    # Format output padding untuk ZeroPadding2D adalah ((padding_atas, padding_bawah), (padding_kiri, padding_kanan)).
    # Padding atas = correct[0] - adjust[0] (mengurangi 1 jika tinggi input ganjil)
    # Padding bawah = correct[0]
    # Padding kiri = correct[1] - adjust[1] (mengurangi 1 jika lebar input ganjil)
    # Padding kanan = correct[1]
    # Penyesuaian ini (mengurangi padding di satu sisi) memastikan output memiliki dimensi yang tepat setelah downsampling
    # ketika dimensi input awalnya ganjil.
    return (
        (correct[0] - adjust[0], correct[0]), # Padding (tinggi atas, tinggi bawah)
        (correct[1] - adjust[1], correct[1]), # Padding (lebar kiri, lebar kanan)
    )

# Reference: https://git.io/JKgtC

# Blok ini mengimplementasikan Inverted Residual Block, sebuah konsep dari MobileNetV2.
# Disebut "inverted" karena memperluas (expand) jumlah kanal di tengah blok,
# berbeda dengan blok residual tradisional yang menyempitkan (bottleneck) kanal.
def inverted_residual_block(x, expanded_channels, output_channels, strides=1):
    """
    Mendefinisikan Inverted Residual Block.

    Struktur: 1x1 Conv (Expand) -> 3x3 Depthwise Conv -> 1x1 Conv (Project)
    Ditambah Residual Connection jika dimensi input/output cocok dan strides=1.

    Args:
        x: Tensor input ke blok.
        expanded_channels: Jumlah kanal setelah layer ekspansi 1x1.
        output_channels: Jumlah kanal output setelah layer proyeksi 1x1.
        strides: Langkah untuk Depthwise Conv. Strides=2 melakukan downsampling. Default 1.

    Returns:
        Tensor output dari blok inverted residual.
    """
    # Simpan input tensor untuk residual connection nanti
    input_shape = x.shape

    # Langkah 1: Ekspansi (Expansion)
    # Konvolusi 1x1 untuk meningkatkan jumlah kanal
    m = layers.Conv2D(expanded_channels, 1, padding="same", use_bias=False)(x)
    m = layers.BatchNormalization()(m)
    m = keras.activations.swish(m) # Menggunakan aktivasi Swish

    # Langkah 2: Depthwise Convolution
    # Konvolusi 3x3 yang beroperasi secara independen di setiap kanal
    # Jika strides=2, kita perlu padding khusus (menggunakan fungsi correct_pad)
    if strides == 2:
        # Menambahkan padding nol sebelum depthwise conv jika downsampling
        m = layers.ZeroPadding2D(padding=correct_pad(m, 3))(m)

    # Melakukan Depthwise Convolution
    m = layers.DepthwiseConv2D(
        kernel_size=3, # Ukuran kernel 3x3
        strides=strides, # Menggunakan stride yang ditentukan
        # Padding 'same' jika stride 1, 'valid' jika stride 2 (setelah ZeroPadding2D)
        padding="same" if strides == 1 else "valid",
        use_bias=False # Biasanya tanpa bias diikuti Batch Normalization
    )(m)
    m = layers.BatchNormalization()(m)
    m = keras.activations.swish(m) # Menggunakan aktivasi Swish

    # Langkah 3: Proyeksi (Projection)
    # Konvolusi 1x1 untuk mengurangi (memproyeksikan) jumlah kanal kembali
    m = layers.Conv2D(output_channels, 1, padding="same", use_bias=False)(m)
    m = layers.BatchNormalization()(m)
    # Catatan: Tidak ada aktivasi non-linear setelah proyeksi 1x1 di MobileNetV2,
    # ini disengaja untuk mempertahankan kemampuan merepresentasikan manifold berdimensi rendah.

    # Langkah 4: Residual Connection (jika memungkinkan)
    # Residual connection hanya ditambahkan jika:
    # 1. Jumlah kanal input sama dengan jumlah kanal output blok
    # 2. Tidak ada downsampling (strides == 1)
    # Ini memastikan dimensi spasial dan kanal cocok untuk operasi penjumlahan.
    # keras.ops.equal digunakan untuk perbandingan tensor.
    if keras.ops.equal(input_shape[-1], output_channels) and strides == 1:
        # Jika kondisi terpenuhi, tambahkan input asli ke output blok
        return layers.Add()([m, x])
    else:
        # Jika kondisi tidak terpenuhi (downsampling atau jumlah kanal berbeda),
        # kembalikan hanya output dari blok (tanpa residual connection)
        return m

# Reference:
# https://keras.io/examples/vision/image_classification_with_vision_transformer/

# MLP block seperti yang sering digunakan dalam arsitektur Vision Transformer.
def mlp(x, hidden_units, dropout_rate):
    """
    Mendefinisikan blok Multi-Layer Perceptron (MLP) dengan aktivasi Swish dan Dropout.

    Args:
        x: Tensor input ke blok MLP.
        hidden_units: List integer yang menentukan jumlah unit (neuron)
                      di setiap layer Dense dalam MLP.
        dropout_rate: Tingkat dropout yang akan diterapkan setelah setiap layer Dense.

    Returns:
        Tensor output setelah melewati semua layer Dense dan Dropout.
    """
    # Iterasi melalui setiap jumlah unit yang ditentukan dalam list hidden_units
    for units in hidden_units:
        # Langkah 1: Layer Dense (Fully Connected)
        # Menambahkan layer Dense dengan jumlah unit tertentu dan aktivasi Swish.
        # Layer Dense menerapkan transformasi linier (x * W + b) diikuti oleh aktivasi.
        x = layers.Dense(units, activation=keras.activations.swish)(x)

        # Langkah 2: Layer Dropout
        # Menerapkan dropout untuk membantu mencegah overfitting.
        # Secara acak menyetel unit input ke 0 pada frekuensi 'dropout_rate' selama training. [1]
        x = layers.Dropout(dropout_rate)(x)

    # Mengembalikan tensor setelah melewati semua layer Dense dan Dropout dalam loop
    return x

# Blok Transformer seperti yang sering digunakan dalam arsitektur Vision Transformer.
def transformer_block(x, transformer_layers, projection_dim, num_heads=2):
    """
    Mendefinisikan satu atau lebih blok Transformer berturut-turut.

    Setiap blok terdiri dari:
    Layer Normalization -> Multi-Head Attention -> Skip Connection ->
    Layer Normalization -> MLP -> Skip Connection

    Args:
        x: Tensor input ke blok/rantai blok Transformer.
           Biasanya berbentuk (batch_size, num_patches, embedding_dim) atau serupa.
        transformer_layers: Jumlah blok Transformer untuk ditumpuk.
        projection_dim: Dimensi yang digunakan untuk key, query, dan value di Multi-Head Attention.
                        Juga merupakan dimensi input/output dari MLP.
        num_heads: Jumlah kepala perhatian di Multi-Head Attention. Default 2.

    Returns:
        Tensor output setelah melewati jumlah blok Transformer yang ditentukan.
    """
    # Loop untuk menumpuk (stack) beberapa blok Transformer
    for _ in range(transformer_layers):
        # Simpan input saat ini untuk skip connection pertama
        input_tensor = x

        # Layer Normalization 1.
        # Menormalisasi input di sepanjang dimensi terakhir (dimensi fitur/embedding).
        # Ini membantu menstabilkan training. epsilon ditambahkan untuk stabilitas numerik.
        x1 = layers.LayerNormalization(epsilon=1e-6)(x)

        # Create a multi-head attention layer.
        # Layer yang memungkinkan model untuk secara bersamaan memperhatikan dari representasi subspace yang berbeda.
        # Kueri (Query), Kunci (Key), dan Nilai (Value) semuanya berasal dari input yang sama (Self-Attention).
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads,      # Jumlah kepala perhatian
            key_dim=projection_dim,   # Dimensi key/value per kepala perhatian
            dropout=0.1               # Tingkat dropout dalam mekanisme perhatian
        )(x1, x1) # Input Q, K, V adalah x1 (Self-Attention)

        # Skip connection 1.
        # Menambahkan output dari sub-layer attention ke input aslinya (sebelum normalisasi).
        # Ini membantu aliran gradien selama backpropagation.
        x2 = layers.Add()([attention_output, input_tensor]) # Menggunakan input_tensor yang disimpan

        # Layer Normalization 2.
        # Menormalisasi output dari skip connection perhatian.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)

        # MLP (Feed-Forward Network).
        # Melewatkan output yang dinormalisasi melalui jaringan saraf terhubung penuh.
        # Menggunakan fungsi mlp yang didefinisikan sebelumnya.
        # Hidden units biasanya 2x dimensi input, lalu kembali ke dimensi input. [2]
        x3 = mlp(
            x3,
            hidden_units=[x.shape[-1] * 2, x.shape[-1]], # Pola umum untuk MLP di Transformer
            dropout_rate=0.1,
        )

        # Skip connection 2.
        # Menambahkan output dari sub-layer MLP ke inputnya (output dari skip connection pertama).
        x = layers.Add()([x3, x2]) # Menggunakan x2 sebagai input untuk skip connection ini

    # Mengembalikan tensor setelah melewati semua blok Transformer yang ditentukan
    return x


def mobilevit_block(x, num_blocks, projection_dim, strides=1):
    """
    Mendefinisikan blok MobileViT yang menggabungkan konvolusi lokal dan pemrosesan global Transformer.

    Args:
        x: Tensor input ke blok MobileViT. Biasanya output dari blok sebelumnya.
        num_blocks: Jumlah blok Transformer yang akan digunakan di bagian global.
        projection_dim: Dimensi yang digunakan di dalam blok Transformer dan untuk konvolusi proyeksi.
        strides: Langkah untuk downsampling awal menggunakan conv_block. Default 1.

    Returns:
        Tensor output dari blok MobileViT yang telah memadukan fitur lokal dan global.
    """
    # Local projection with convolutions.
    local_features = conv_block(x, filters=projection_dim, strides=strides)
    local_features = conv_block(
        local_features, filters=projection_dim, kernel_size=1, strides=strides
    )

    # Unfold into patches and then pass through Transformers.
    num_patches = int((local_features.shape[1] * local_features.shape[2]) / patch_size)
    non_overlapping_patches = layers.Reshape((patch_size, num_patches, projection_dim))(
        local_features
    )
    global_features = transformer_block(
        non_overlapping_patches, num_blocks, projection_dim
    )

    # Fold into conv-like feature-maps.
    folded_feature_map = layers.Reshape((*local_features.shape[1:-1], projection_dim))(
        global_features
    )

    # Apply point-wise conv -> concatenate with the input features.
    folded_feature_map = conv_block(
        folded_feature_map, filters=x.shape[-1], kernel_size=1, strides=strides
    )
    local_global_features = layers.Concatenate(axis=-1)([x, folded_feature_map])

    # Fuse the local and global features using a convoluion layer.
    local_global_features = conv_block(
        local_global_features, filters=projection_dim, strides=strides
    )

    return local_global_features

# %% [markdown]
# **More on the MobileViT block**:
#
# * First, the feature representations (A) go through convolution blocks that capture local
# relationships. The expected shape of a single entry here would be `(h, w, num_channels)`.
# * Then they get unfolded into another vector with shape `(p, n, num_channels)`,
# where `p` is the area of a small patch, and `n` is `(h * w) / p`. So, we end up with `n`
# non-overlapping patches.
# * This unfolded vector is then passed through a Tranformer block that captures global
# relationships between the patches.
# * The output vector (B) is again folded into a vector of shape `(h, w, num_channels)`
# resembling a feature map coming out of convolutions.
#
# Vectors A and B are then passed through two more convolutional layers to fuse the local
# and global representations. Notice how the spatial resolution of the final vector remains
# unchanged at this point. The authors also present an explanation of how the MobileViT
# block resembles a convolution block of a CNN. For more details, please refer to the
# original paper.

# %% [markdown]
# Next, we combine these blocks together and implement the MobileViT architecture (XXS
# variant). The following figure (taken from the original paper) presents a schematic
# representation of the architecture:
#
# ![](https://i.ibb.co/sRbVRBN/image.png)

# %%
# Fungsi utama untuk membangun model MobileViT secara keseluruhan.
def create_mobilevit(num_classes=num_classes):
    """
    Membangun arsitektur model MobileViT.

    Model ini terdiri dari:
    - Layer input dan normalisasi awal.
    - Tahap-tahap yang menggabungkan Inverted Residual Blocks (MV2) dan MobileViT Blocks.
    - Downsampling dilakukan pada tahap-tahap awal dan di antara blok-blok utama.
    - Kepala klasifikasi di akhir.

    Args:
        num_classes: Jumlah kelas output untuk tugas klasifikasi. Default menggunakan variabel global num_classes.

    Returns:
        Instance model Keras Sequential atau Model.
    """
    # Mendefinisikan layer input model.
    # Model akan menerima input gambar dengan ukuran (image_size, image_size, 3)
    # image_size adalah variabel global yang didefinisikan sebelumnya (misal 256x256).
    # 3 menandakan channel warna RGB.
    inputs = keras.Input((image_size, image_size, 3))

    # Normalisasi awal: Menskalakan nilai piksel dari rentang [0, 255] ke [0.0, 1.0].
    x = layers.Rescaling(scale=1.0 / 255)(inputs)

    # Tahap Awal (Initial conv-stem -> MV2 block).
    # Memulai jaringan dengan blok konvolusi awal.
    x = conv_block(x, filters=16)
    # Diikuti oleh satu Inverted Residual Block (MobileNetV2 block) tanpa downsampling (stride default 1).
    # expanded_channels = 16 * expansion_factor, output_channels = 16.
    x = inverted_residual_block(
        x, expanded_channels=16 * expansion_factor, output_channels=16
    )

    # Tahap Downsampling dengan MV2 block.
    # Melakukan downsampling pertama dengan Inverted Residual Block menggunakan strides=2.
    # expanded_channels = 16 * expansion_factor, output_channels = 24.
    x = inverted_residual_block(
        x, expanded_channels=16 * expansion_factor, output_channels=24, strides=2
    )
    # Diikuti oleh dua Inverted Residual Block tambahan tanpa downsampling.
    # expanded_channels = 24 * expansion_factor, output_channels = 24.
    x = inverted_residual_block(
        x, expanded_channels=24 * expansion_factor, output_channels=24
    )
    x = inverted_residual_block(
        x, expanded_channels=24 * expansion_factor, output_channels=24
    )

    # Tahap Pertama MV2 -> MobileViT block.
    # Melakukan downsampling lagi dengan Inverted Residual Block menggunakan strides=2.
    # expanded_channels = 24 * expansion_factor, output_channels = 48.
    x = inverted_residual_block(
        x, expanded_channels=24 * expansion_factor, output_channels=48, strides=2
    )
    # Diikuti oleh blok MobileViT utama.
    # Menggunakan 2 blok Transformer di dalamnya (num_blocks=2).
    # Dimensi proyeksi fitur global adalah 64.
    x = mobilevit_block(x, num_blocks=2, projection_dim=64)

    # Tahap Kedua MV2 -> MobileViT block.
    # Melakukan downsampling lagi dengan Inverted Residual Block menggunakan strides=2.
    # expanded_channels = 64 * expansion_factor, output_channels = 64.
    x = inverted_residual_block(
        x, expanded_channels=64 * expansion_factor, output_channels=64, strides=2
    )
    # Diikuti oleh blok MobileViT kedua.
    # Menggunakan 4 blok Transformer di dalamnya (num_blocks=4).
    # Dimensi proyeksi fitur global adalah 80.
    x = mobilevit_block(x, num_blocks=4, projection_dim=80)

    # Tahap Ketiga MV2 -> MobileViT block.
    # Melakukan downsampling terakhir dengan Inverted Residual Block menggunakan strides=2.
    # expanded_channels = 80 * expansion_factor, output_channels = 80.
    x = inverted_residual_block(
        x, expanded_channels=80 * expansion_factor, output_channels=80, strides=2
    )
    # Diikuti oleh blok MobileViT ketiga.
    # Menggunakan 3 blok Transformer di dalamnya (num_blocks=3).
    # Dimensi proyeksi fitur global adalah 96.
    x = mobilevit_block(x, num_blocks=3, projection_dim=96)
    # Menambahkan konvolusi 1x1 di akhir tahap fitur ekstraksi.
    # Filter=320, kernel=1, strides=1. Ini meningkatkan jumlah kanal sebelum kepala klasifikasi.
    x = conv_block(x, filters=320, kernel_size=1, strides=1)

    # Kepala Klasifikasi (Classification head).
    # Melakukan Average Pooling global 2D. Ini merata-ratakan fitur spasial di seluruh peta fitur,
    # mengurangi dimensi spasial menjadi 1x1.
    x = layers.GlobalAvgPool2D()(x)
    # Layer Dense (Fully Connected) terakhir untuk output klasifikasi.
    # Jumlah unit = num_classes.
    # Aktivasi "softmax" untuk menghasilkan probabilitas distribusi di atas kelas.
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    # Membuat model Keras menggunakan input dan output yang ditentukan.
    # Ini adalah Functional API Keras.
    return keras.Model(inputs, outputs)


# Membuat instance model MobileViT.
mobilevit_xxs = create_mobilevit()
# Menampilkan ringkasan model, termasuk layer dan jumlah parameter.
mobilevit_xxs.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 256, 256,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        448 │ rescaling[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │        512 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu (Silu)         │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 128, 128,  │        288 │ silu[0][0]        │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_1 (Silu)       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │        512 │ silu_1[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │        512 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_2 (Silu)       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d      │ (None, 129, 129,  │          0 │ silu_2[0][0]      │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (None, 64, 64,    │        288 │ zero_padding2d[0… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_3 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │        768 │ silu_3[0][0]      │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │      1,152 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_4 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (None, 64, 64,    │        432 │ silu_4[0][0]      │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_5 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │      1,152 │ silu_5[0][0]      │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │      1,152 │ add_1[0][0]       │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_6 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_3  │ (None, 64, 64,    │        432 │ silu_6[0][0]      │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_7 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │      1,152 │ silu_7[0][0]      │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │      1,152 │ add_2[0][0]       │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_8 (Silu)       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1    │ (None, 65, 65,    │          0 │ silu_8[0][0]      │
# │ (ZeroPadding2D)     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4  │ (None, 32, 32,    │        432 │ zero_padding2d_1… │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_9 (Silu)       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │      2,304 │ silu_9[0][0]      │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │     27,712 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │      4,160 │ conv2d_11[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 4, 256,    │          0 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 4, 256,    │        128 │ reshape[0][0]     │
# │ (LayerNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 256,    │     33,216 │ layer_normalizat… │
# │ (MultiHeadAttentio… │ 64)               │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 4, 256,    │          0 │ multi_head_atten… │
# │                     │ 64)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 256,    │        128 │ add_3[0][0]       │
# │ (LayerNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4, 256,    │      8,320 │ layer_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 4, 256,    │          0 │ dense[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 4, 256,    │      8,256 │ dropout_1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 4, 256,    │          0 │ dense_1[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 4, 256,    │          0 │ dropout_2[0][0],  │
# │                     │ 64)               │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 256,    │        128 │ add_4[0][0]       │
# │ (LayerNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 256,    │     33,216 │ layer_normalizat… │
# │ (MultiHeadAttentio… │ 64)               │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 4, 256,    │          0 │ multi_head_atten… │
# │                     │ 64)               │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 256,    │        128 │ add_5[0][0]       │
# │ (LayerNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4, 256,    │      8,320 │ layer_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 4, 256,    │          0 │ dense_2[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 4, 256,    │      8,256 │ dropout_4[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 4, 256,    │          0 │ dense_3[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 4, 256,    │          0 │ dropout_5[0][0],  │
# │                     │ 64)               │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 32, 32,    │          0 │ add_6[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │      3,120 │ reshape_1[0][0]   │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 96)               │            │ conv2d_13[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 32, 32,    │     55,360 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 32, 32,    │      8,192 │ conv2d_14[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_10 (Silu)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_2    │ (None, 33, 33,    │          0 │ silu_10[0][0]     │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_5  │ (None, 16, 16,    │      1,152 │ zero_padding2d_2… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_11 (Silu)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 16, 16,    │      8,192 │ silu_11[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 16, 16,    │     46,160 │ batch_normalizat… │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 16, 16,    │      6,480 │ conv2d_17[0][0]   │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 4, 64, 80) │          0 │ conv2d_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ reshape_2[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64, 80) │     51,760 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 4, 64, 80) │          0 │ multi_head_atten… │
# │                     │                   │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 4, 64,     │     12,960 │ layer_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 4, 64,     │          0 │ dense_4[0][0]     │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 4, 64, 80) │     12,880 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 4, 64, 80) │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 4, 64, 80) │          0 │ dropout_8[0][0],  │
# │                     │                   │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64, 80) │     51,760 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 4, 64, 80) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 4, 64,     │     12,960 │ layer_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 4, 64,     │          0 │ dense_6[0][0]     │
# │ (Dropout)           │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 4, 64, 80) │     12,880 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 4, 64, 80) │          0 │ dense_7[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 4, 64, 80) │          0 │ dropout_11[0][0], │
# │                     │                   │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64, 80) │     51,760 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 4, 64, 80) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 4, 64,     │     12,960 │ layer_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 4, 64,     │          0 │ dense_8[0][0]     │
# │ (Dropout)           │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 4, 64, 80) │     12,880 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 4, 64, 80) │          0 │ dense_9[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 4, 64, 80) │          0 │ dropout_14[0][0], │
# │                     │                   │            │ add_11[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64, 80) │     51,760 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 4, 64, 80) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64, 80) │        160 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 4, 64,     │     12,960 │ layer_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 4, 64,     │          0 │ dense_10[0][0]    │
# │ (Dropout)           │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 4, 64, 80) │     12,880 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 4, 64, 80) │          0 │ dense_11[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 4, 64, 80) │          0 │ dropout_17[0][0], │
# │                     │                   │            │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 16, 16,    │          0 │ add_14[0][0]      │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 16, 16,    │      5,184 │ reshape_3[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 128)              │            │ conv2d_19[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 16, 16,    │     92,240 │ concatenate_1[0]… │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 16, 16,    │     12,800 │ conv2d_20[0][0]   │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        640 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_12 (Silu)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_3    │ (None, 17, 17,    │          0 │ silu_12[0][0]     │
# │ (ZeroPadding2D)     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (None, 8, 8, 160) │      1,440 │ zero_padding2d_3… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 160) │        640 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ silu_13 (Silu)      │ (None, 8, 8, 160) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 8, 8, 80)  │     12,800 │ silu_13[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 80)  │        320 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 8, 8, 96)  │     69,216 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 8, 8, 96)  │      9,312 │ conv2d_23[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 4, 16, 96) │          0 │ conv2d_24[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ reshape_4[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 16, 96) │     74,400 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 4, 16, 96) │          0 │ multi_head_atten… │
# │                     │                   │            │ reshape_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_15[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 4, 16,     │     18,624 │ layer_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 4, 16,     │          0 │ dense_12[0][0]    │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 4, 16, 96) │     18,528 │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 4, 16, 96) │          0 │ dense_13[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 4, 16, 96) │          0 │ dropout_20[0][0], │
# │                     │                   │            │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_16[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 16, 96) │     74,400 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 4, 16, 96) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_17[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 4, 16,     │     18,624 │ layer_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 4, 16,     │          0 │ dense_14[0][0]    │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 4, 16, 96) │     18,528 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 4, 16, 96) │          0 │ dense_15[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 4, 16, 96) │          0 │ dropout_23[0][0], │
# │                     │                   │            │ add_17[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_18[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 16, 96) │     74,400 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 4, 16, 96) │          0 │ multi_head_atten… │
# │                     │                   │            │ add_18[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 16, 96) │        192 │ add_19[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 4, 16,     │     18,624 │ layer_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 4, 16,     │          0 │ dense_16[0][0]    │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 4, 16, 96) │     18,528 │ dropout_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 4, 16, 96) │          0 │ dense_17[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 4, 16, 96) │          0 │ dropout_26[0][0], │
# │                     │                   │            │ add_19[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, 8, 8, 96)  │          0 │ add_20[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 8, 8, 80)  │      7,760 │ reshape_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 8, 8, 160) │          0 │ batch_normalizat… │
# │ (Concatenate)       │                   │            │ conv2d_25[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 8, 8, 96)  │    138,336 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 8, 8, 320) │     31,040 │ conv2d_26[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 320)       │          0 │ conv2d_27[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 26)        │      8,346 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,314,362 (5.01 MB)
#  Trainable params: 1,311,818 (5.00 MB)
#  Non-trainable params: 2,544 (9.94 KB)

# %% [markdown]
# ## Load & Prepare Dataset

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Direktori data
train_dir = '/content/drive/MyDrive/PDM/Model/train'
val_dir = '/content/drive/MyDrive/PDM/Model/val'
#test_dir = '/content/drive/MyDrive/PDM/landmark-gambar/test'

# Augmentasi data training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    #rotation_range=20,  # Rotasi acak hingga 20 derajat
    #width_shift_range=0.2,  # Pergeseran horizontal acak hingga 20% dari lebar
    #height_shift_range=0.2,  # Pergeseran vertikal acak hingga 20% dari tinggi
    #shear_range=0.2,  # Shear acak hingga 20 derajat
    #zoom_range=0.2,  # Zoom acak hingga 20%
    #horizontal_flip=True,  # Flip horizontal acak
    #fill_mode='nearest'  # Cara mengisi piksel kosong setelah transformasi
)

# Data generator untuk training
train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# Data generator untuk validasi (tanpa augmentasi)
val_datagen = ImageDataGenerator(rescale=1./255)
val_gen = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Data generator untuk testing (tanpa augmentasi)
#test_datagen = ImageDataGenerator(rescale=1./255)
#test_gen = test_datagen.flow_from_directory(
    #test_dir,
    #target_size=(img_size, img_size),
   # batch_size=batch_size,
  #  class_mode='categorical',
 #   shuffle=False
#)

# %%
mobilevit_xxs.compile(
    optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)


# Melakukan training dengan callback
history = mobilevit_xxs.fit(
    train_gen,
    epochs=num_epochs,
    validation_data=val_gen,
)
# Out:
# Epoch 1/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 192s 2s/step - accuracy: 0.0396 - loss: 3.2540 - val_accuracy: 0.0456 - val_loss: 3.2562
# Epoch 2/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 514ms/step - accuracy: 0.0440 - loss: 3.2401 - val_accuracy: 0.0456 - val_loss: 3.2588
# Epoch 3/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 42s 526ms/step - accuracy: 0.0525 - loss: 3.2176 - val_accuracy: 0.0345 - val_loss: 3.2670
# Epoch 4/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 41s 523ms/step - accuracy: 0.0660 - loss: 3.1814 - val_accuracy: 0.0345 - val_loss: 3.3001
# Epoch 5/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 539ms/step - accuracy: 0.0830 - loss: 3.0763 - val_accuracy: 0.0345 - val_loss: 3.4279
# Epoch 6/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 510ms/step - accuracy: 0.0769 - loss: 2.9839 - val_accuracy: 0.0345 - val_loss: 3.6596
# Epoch 7/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 42s 532ms/step - accuracy: 0.0916 - loss: 2.8998 - val_accuracy: 0.0345 - val_loss: 4.1730
# Epoch 8/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 520ms/step - accuracy: 0.1231 - loss: 2.8436 - val_accuracy: 0.0345 - val_loss: 5.2889
# Epoch 9/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 546ms/step - accuracy: 0.1456 - loss: 2.8122 - val_accuracy: 0.0345 - val_loss: 6.6174
# Epoch 10/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 528ms/step - accuracy: 0.1518 - loss: 2.7632 - val_accuracy: 0.0345 - val_loss: 7.4819
# Epoch 11/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 550ms/step - accuracy: 0.1672 - loss: 2.7051 - val_accuracy: 0.0345 - val_loss: 8.3983
# Epoch 12/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 526ms/step - accuracy: 0.1669 - loss: 2.6666 - val_accuracy: 0.0345 - val_loss: 8.7962
# Epoch 13/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 549ms/step - accuracy: 0.1936 - loss: 2.6074 - val_accuracy: 0.0345 - val_loss: 9.0366
# Epoch 14/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 527ms/step - accuracy: 0.2036 - loss: 2.5353 - val_accuracy: 0.0366 - val_loss: 8.0127
# Epoch 15/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 534ms/step - accuracy: 0.2252 - loss: 2.4939 - val_accuracy: 0.0557 - val_loss: 7.1719
# Epoch 16/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 523ms/step - accuracy: 0.2427 - loss: 2.4467 - val_accuracy: 0.0811 - val_loss: 5.5381
# Epoch 17/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 524ms/step - accuracy: 0.2548 - loss: 2.4503 - val_accuracy: 0.0864 - val_loss: 5.5418
# Epoch 18/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 41s 525ms/step - accuracy: 0.2490 - loss: 2.3983 - val_accuracy: 0.0901 - val_loss: 5.2559
# Epoch 19/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 523ms/step - accuracy: 0.2731 - loss: 2.3809 - val_accuracy: 0.0832 - val_loss: 5.0355
# Epoch 20/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 530ms/step - accuracy: 0.2703 - loss: 2.3706 - val_accuracy: 0.1060 - val_loss: 5.1240
# Epoch 21/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 42s 541ms/step - accuracy: 0.2994 - loss: 2.3190 - val_accuracy: 0.0949 - val_loss: 5.7942
# Epoch 22/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 525ms/step - accuracy: 0.3102 - loss: 2.2717 - val_accuracy: 0.0960 - val_loss: 6.9902
# Epoch 23/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 534ms/step - accuracy: 0.3348 - loss: 2.2591 - val_accuracy: 0.1002 - val_loss: 8.3581
# Epoch 24/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 528ms/step - accuracy: 0.3332 - loss: 2.2277 - val_accuracy: 0.0822 - val_loss: 13.1122
# Epoch 25/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 538ms/step - accuracy: 0.3529 - loss: 2.1806 - val_accuracy: 0.0970 - val_loss: 6.3283
# Epoch 26/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 522ms/step - accuracy: 0.3547 - loss: 2.1235 - val_accuracy: 0.0954 - val_loss: 7.3399
# Epoch 27/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 529ms/step - accuracy: 0.3562 - loss: 2.0912 - val_accuracy: 0.0827 - val_loss: 6.6960
# Epoch 28/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 520ms/step - accuracy: 0.3622 - loss: 2.0747 - val_accuracy: 0.0854 - val_loss: 6.7582
# Epoch 29/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 525ms/step - accuracy: 0.4124 - loss: 2.0263 - val_accuracy: 0.0976 - val_loss: 7.2414
# Epoch 30/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 514ms/step - accuracy: 0.4227 - loss: 1.9893 - val_accuracy: 0.0848 - val_loss: 8.5376
# Epoch 31/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 504ms/step - accuracy: 0.4021 - loss: 1.9957 - val_accuracy: 0.0817 - val_loss: 7.6816
# Epoch 32/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 532ms/step - accuracy: 0.4141 - loss: 1.9403 - val_accuracy: 0.0811 - val_loss: 7.8714
# Epoch 33/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 543ms/step - accuracy: 0.4251 - loss: 1.9157 - val_accuracy: 0.0907 - val_loss: 8.6956
# Epoch 34/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 518ms/step - accuracy: 0.4435 - loss: 1.9232 - val_accuracy: 0.0912 - val_loss: 8.2811
# Epoch 35/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 510ms/step - accuracy: 0.4575 - loss: 1.8743 - val_accuracy: 0.0811 - val_loss: 8.8121
# Epoch 36/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 532ms/step - accuracy: 0.4644 - loss: 1.8556 - val_accuracy: 0.0779 - val_loss: 10.9795
# Epoch 37/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 519ms/step - accuracy: 0.4631 - loss: 1.7937 - val_accuracy: 0.0461 - val_loss: 15.4588
# Epoch 38/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 529ms/step - accuracy: 0.4790 - loss: 1.7938 - val_accuracy: 0.0764 - val_loss: 12.3360
# Epoch 39/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 539ms/step - accuracy: 0.4858 - loss: 1.7499 - val_accuracy: 0.0806 - val_loss: 11.4225
# Epoch 40/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 526ms/step - accuracy: 0.4988 - loss: 1.7266 - val_accuracy: 0.0785 - val_loss: 13.9267
# Epoch 41/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 521ms/step - accuracy: 0.5274 - loss: 1.6821 - val_accuracy: 0.0642 - val_loss: 14.3329
# Epoch 42/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 542ms/step - accuracy: 0.5299 - loss: 1.6997 - val_accuracy: 0.0753 - val_loss: 14.0068
# Epoch 43/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 40s 527ms/step - accuracy: 0.5370 - loss: 1.6207 - val_accuracy: 0.0758 - val_loss: 10.9780
# Epoch 44/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 523ms/step - accuracy: 0.5179 - loss: 1.6480 - val_accuracy: 0.0960 - val_loss: 6.2271
# Epoch 45/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 531ms/step - accuracy: 0.5272 - loss: 1.5963 - val_accuracy: 0.0896 - val_loss: 10.0379
# Epoch 46/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 531ms/step - accuracy: 0.5443 - loss: 1.5777 - val_accuracy: 0.0769 - val_loss: 11.1010
# Epoch 47/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 41s 530ms/step - accuracy: 0.5375 - loss: 1.6020 - val_accuracy: 0.0838 - val_loss: 10.9554
# Epoch 48/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 530ms/step - accuracy: 0.5531 - loss: 1.5441 - val_accuracy: 0.0848 - val_loss: 11.5811
# Epoch 49/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 522ms/step - accuracy: 0.5623 - loss: 1.5149 - val_accuracy: 0.0832 - val_loss: 13.9947
# Epoch 50/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 527ms/step - accuracy: 0.5723 - loss: 1.4759 - val_accuracy: 0.0986 - val_loss: 9.5536
# Epoch 51/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 522ms/step - accuracy: 0.5879 - loss: 1.4460 - val_accuracy: 0.0827 - val_loss: 11.9241
# Epoch 52/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 533ms/step - accuracy: 0.5922 - loss: 1.4353 - val_accuracy: 0.0530 - val_loss: 15.6744
# Epoch 53/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 522ms/step - accuracy: 0.5785 - loss: 1.4569 - val_accuracy: 0.0875 - val_loss: 11.7453
# Epoch 54/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 543ms/step - accuracy: 0.5898 - loss: 1.4023 - val_accuracy: 0.0875 - val_loss: 11.3157
# Epoch 55/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 539ms/step - accuracy: 0.6231 - loss: 1.3434 - val_accuracy: 0.0832 - val_loss: 11.9693
# Epoch 56/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 518ms/step - accuracy: 0.6116 - loss: 1.3614 - val_accuracy: 0.0923 - val_loss: 10.9957
# Epoch 57/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 526ms/step - accuracy: 0.6152 - loss: 1.3475 - val_accuracy: 0.0779 - val_loss: 11.8019
# Epoch 58/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 544ms/step - accuracy: 0.6336 - loss: 1.2940 - val_accuracy: 0.1013 - val_loss: 9.8903
# Epoch 59/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 39s 518ms/step - accuracy: 0.6414 - loss: 1.2857 - val_accuracy: 0.1373 - val_loss: 5.9027
# Epoch 60/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 43s 543ms/step - accuracy: 0.6346 - loss: 1.2929 - val_accuracy: 0.0923 - val_loss: 11.6142

# %% [markdown]
# ## Train a MobileViT (XXS) model

# %%
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
loss_fn = keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing_factor)


def run_experiment(epochs=num_epochs):
    mobilevit_xxs = create_mobilevit(num_classes=num_classes)
    mobilevit_xxs.compile(optimizer=optimizer, loss=loss_fn, metrics=["accuracy"])

    # When using `save_weights_only=True` in `ModelCheckpoint`, the filepath provided must end in `.weights.h5`
    checkpoint_filepath = "/tmp/checkpoint.weights.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    mobilevit_xxs.fit(
        train_gen,
        validation_data=val_gen,
        epochs=epochs,
        callbacks=[checkpoint_callback],
    )
    mobilevit_xxs.load_weights(checkpoint_filepath)
    _, accuracy = mobilevit_xxs.evaluate(val_gen)
    print(f"Validation accuracy: {round(accuracy * 100, 2)}%")
    return mobilevit_xxs


mobilevit_xxs = run_experiment()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 215s 2s/step - accuracy: 0.1692 - loss: 2.8714 - val_accuracy: 0.0345 - val_loss: 3.4748
# Epoch 2/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 538ms/step - accuracy: 0.7014 - loss: 1.5729 - val_accuracy: 0.0371 - val_loss: 4.2392
# Epoch 3/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 536ms/step - accuracy: 0.8459 - loss: 1.1597 - val_accuracy: 0.0382 - val_loss: 3.8285
# Epoch 4/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 518ms/step - accuracy: 0.9021 - loss: 1.0059 - val_accuracy: 0.0371 - val_loss: 3.4876
# Epoch 5/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 535ms/step - accuracy: 0.9342 - loss: 0.9047 - val_accuracy: 0.0345 - val_loss: 4.1114
# Epoch 6/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 526ms/step - accuracy: 0.9493 - loss: 0.8554 - val_accuracy: 0.0345 - val_loss: 3.9230
# Epoch 7/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 534ms/step - accuracy: 0.9647 - loss: 0.7999 - val_accuracy: 0.0350 - val_loss: 4.5343
# Epoch 8/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 537ms/step - accuracy: 0.9728 - loss: 0.7860 - val_accuracy: 0.0382 - val_loss: 3.9558
# Epoch 9/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 732ms/step - accuracy: 0.9798 - loss: 0.7578 - val_accuracy: 0.0488 - val_loss: 5.9126
# Epoch 10/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 535ms/step - accuracy: 0.9835 - loss: 0.7433 - val_accuracy: 0.0414 - val_loss: 4.7740
# Epoch 11/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 545ms/step - accuracy: 0.9970 - loss: 0.6969 - val_accuracy: 0.1394 - val_loss: 3.5175
# Epoch 12/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 533ms/step - accuracy: 0.9965 - loss: 0.6894 - val_accuracy: 0.0536 - val_loss: 5.7445
# Epoch 13/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 541ms/step - accuracy: 0.9992 - loss: 0.6620 - val_accuracy: 0.0525 - val_loss: 5.6270
# Epoch 14/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 540ms/step - accuracy: 1.0000 - loss: 0.6463 - val_accuracy: 0.8881 - val_loss: 1.1051
# Epoch 15/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 543ms/step - accuracy: 1.0000 - loss: 0.6423 - val_accuracy: 0.0742 - val_loss: 3.9264
# Epoch 16/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 533ms/step - accuracy: 1.0000 - loss: 0.6382 - val_accuracy: 0.5175 - val_loss: 2.0087
# Epoch 17/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 536ms/step - accuracy: 1.0000 - loss: 0.6374 - val_accuracy: 0.1071 - val_loss: 3.4901
# Epoch 18/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 549ms/step - accuracy: 1.0000 - loss: 0.6363 - val_accuracy: 0.9968 - val_loss: 0.6443
# Epoch 19/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 536ms/step - accuracy: 1.0000 - loss: 0.6351 - val_accuracy: 0.2259 - val_loss: 2.8161
# Epoch 20/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 536ms/step - accuracy: 1.0000 - loss: 0.6343 - val_accuracy: 0.9735 - val_loss: 0.8477
# Epoch 21/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 540ms/step - accuracy: 1.0000 - loss: 0.6337 - val_accuracy: 0.9973 - val_loss: 0.6597
# Epoch 22/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 525ms/step - accuracy: 1.0000 - loss: 0.6360 - val_accuracy: 0.9910 - val_loss: 0.7478
# Epoch 23/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 533ms/step - accuracy: 1.0000 - loss: 0.6331 - val_accuracy: 0.0636 - val_loss: 4.0899
# Epoch 24/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 543ms/step - accuracy: 1.0000 - loss: 0.6339 - val_accuracy: 0.0530 - val_loss: 4.1915
# Epoch 25/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 533ms/step - accuracy: 1.0000 - loss: 0.6335 - val_accuracy: 0.1416 - val_loss: 2.9917
# Epoch 26/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 540ms/step - accuracy: 1.0000 - loss: 0.6356 - val_accuracy: 0.6013 - val_loss: 1.8106
# Epoch 27/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 532ms/step - accuracy: 1.0000 - loss: 0.6358 - val_accuracy: 0.2709 - val_loss: 2.6044
# Epoch 28/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 526ms/step - accuracy: 1.0000 - loss: 0.6350 - val_accuracy: 0.0901 - val_loss: 3.6560
# Epoch 29/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 535ms/step - accuracy: 0.9998 - loss: 0.6347 - val_accuracy: 0.0456 - val_loss: 4.6854
# Epoch 30/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 526ms/step - accuracy: 1.0000 - loss: 0.6363 - val_accuracy: 0.0748 - val_loss: 3.7561
# Epoch 31/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 548ms/step - accuracy: 0.9996 - loss: 0.6468 - val_accuracy: 0.0445 - val_loss: 12.5254
# Epoch 32/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 523ms/step - accuracy: 0.9073 - loss: 0.9634 - val_accuracy: 0.0498 - val_loss: 788.4901
# Epoch 33/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 527ms/step - accuracy: 0.9201 - loss: 0.9401 - val_accuracy: 0.0445 - val_loss: 32.1974
# Epoch 34/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 41s 534ms/step - accuracy: 0.9707 - loss: 0.7843 - val_accuracy: 0.1251 - val_loss: 4.5529
# Epoch 35/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 529ms/step - accuracy: 0.9882 - loss: 0.7243 - val_accuracy: 0.4740 - val_loss: 2.0804
# Epoch 36/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 536ms/step - accuracy: 0.9986 - loss: 0.6814 - val_accuracy: 0.2863 - val_loss: 3.0481
# Epoch 37/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 41s 535ms/step - accuracy: 1.0000 - loss: 0.6540 - val_accuracy: 0.9968 - val_loss: 0.6654
# Epoch 38/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 544ms/step - accuracy: 1.0000 - loss: 0.6435 - val_accuracy: 0.9979 - val_loss: 0.6504
# Epoch 39/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 539ms/step - accuracy: 1.0000 - loss: 0.6388 - val_accuracy: 0.9979 - val_loss: 0.6468
# Epoch 40/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 530ms/step - accuracy: 1.0000 - loss: 0.6361 - val_accuracy: 0.9973 - val_loss: 0.6463
# Epoch 41/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 535ms/step - accuracy: 1.0000 - loss: 0.6359 - val_accuracy: 0.9979 - val_loss: 0.6427
# Epoch 42/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 532ms/step - accuracy: 1.0000 - loss: 0.6354 - val_accuracy: 0.9979 - val_loss: 0.6433
# Epoch 43/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 542ms/step - accuracy: 1.0000 - loss: 0.6349 - val_accuracy: 0.9979 - val_loss: 0.6446
# Epoch 44/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 528ms/step - accuracy: 1.0000 - loss: 0.6336 - val_accuracy: 0.9979 - val_loss: 0.6438
# Epoch 45/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 539ms/step - accuracy: 1.0000 - loss: 0.6334 - val_accuracy: 0.9979 - val_loss: 0.6435
# Epoch 46/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 534ms/step - accuracy: 1.0000 - loss: 0.6329 - val_accuracy: 0.6988 - val_loss: 1.6743
# Epoch 47/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 544ms/step - accuracy: 1.0000 - loss: 0.6330 - val_accuracy: 0.9343 - val_loss: 1.1268
# Epoch 48/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 536ms/step - accuracy: 1.0000 - loss: 0.6324 - val_accuracy: 0.9973 - val_loss: 0.6429
# Epoch 49/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 557ms/step - accuracy: 1.0000 - loss: 0.6325 - val_accuracy: 0.9979 - val_loss: 0.6400
# Epoch 50/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 540ms/step - accuracy: 1.0000 - loss: 0.6317 - val_accuracy: 0.9979 - val_loss: 0.6403
# Epoch 51/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 551ms/step - accuracy: 1.0000 - loss: 0.6317 - val_accuracy: 0.9979 - val_loss: 0.6395
# Epoch 52/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 534ms/step - accuracy: 1.0000 - loss: 0.6315 - val_accuracy: 0.9979 - val_loss: 0.6401
# Epoch 53/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 42s 543ms/step - accuracy: 1.0000 - loss: 0.6312 - val_accuracy: 0.9979 - val_loss: 0.6388
# Epoch 54/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 542ms/step - accuracy: 1.0000 - loss: 0.6311 - val_accuracy: 0.9979 - val_loss: 0.6396
# Epoch 55/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 529ms/step - accuracy: 1.0000 - loss: 0.6311 - val_accuracy: 0.9979 - val_loss: 0.6392
# Epoch 56/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 539ms/step - accuracy: 1.0000 - loss: 0.6309 - val_accuracy: 0.1373 - val_loss: 3.2742
# Epoch 57/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 531ms/step - accuracy: 1.0000 - loss: 0.6321 - val_accuracy: 0.9979 - val_loss: 0.6602
# Epoch 58/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 543ms/step - accuracy: 1.0000 - loss: 0.6314 - val_accuracy: 0.9979 - val_loss: 0.6392
# Epoch 59/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 548ms/step - accuracy: 1.0000 - loss: 0.6334 - val_accuracy: 0.9979 - val_loss: 0.6463
# Epoch 60/60
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 543ms/step - accuracy: 1.0000 - loss: 0.6343 - val_accuracy: 0.9963 - val_loss: 0.6640
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 332ms/step - accuracy: 0.9978 - loss: 0.6482
# Validation accuracy: 99.79%

# %%
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
loss_fn = keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing_factor)


def run_experiment(epochs=num_epochs):
    mobilevit_xxs = create_mobilevit(num_classes=num_classes)
    mobilevit_xxs.compile(optimizer=optimizer, loss=loss_fn, metrics=["accuracy"])

    # When using `save_weights_only=True` in `ModelCheckpoint`, the filepath provided must end in `.weights.h5`
    checkpoint_filepath = "/tmp/checkpoint.weights.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    mobilevit_xxs.fit(
        train_gen,
        validation_data=val_gen,
        epochs=epochs,
        callbacks=[checkpoint_callback],
    )
    mobilevit_xxs.load_weights(checkpoint_filepath)
    _, accuracy = mobilevit_xxs.evaluate(val_gen)
    print(f"Validation accuracy: {round(accuracy * 100, 2)}%")
    return mobilevit_xxs


mobilevit_xxs = run_experiment()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2785s 43s/step - accuracy: 0.1954 - loss: 2.8227 - val_accuracy: 0.0382 - val_loss: 3.5766
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 519ms/step - accuracy: 0.7538 - loss: 1.4534 - val_accuracy: 0.0371 - val_loss: 3.5051
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 538ms/step - accuracy: 0.8750 - loss: 1.1021 - val_accuracy: 0.0345 - val_loss: 3.4747
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 536ms/step - accuracy: 0.9150 - loss: 0.9632 - val_accuracy: 0.0345 - val_loss: 3.6915
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 537ms/step - accuracy: 0.9234 - loss: 0.9314 - val_accuracy: 0.0191 - val_loss: 5.8947
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 540ms/step - accuracy: 0.9560 - loss: 0.8301 - val_accuracy: 0.0382 - val_loss: 4.4632
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 535ms/step - accuracy: 0.9729 - loss: 0.7964 - val_accuracy: 0.0191 - val_loss: 4.0065
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 539ms/step - accuracy: 0.9862 - loss: 0.7486 - val_accuracy: 0.0191 - val_loss: 4.2725
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 545ms/step - accuracy: 0.9957 - loss: 0.7116 - val_accuracy: 0.0387 - val_loss: 4.7751
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 553ms/step - accuracy: 0.9961 - loss: 0.6979 - val_accuracy: 0.1204 - val_loss: 3.6009
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 568ms/step - accuracy: 0.9972 - loss: 0.6912 - val_accuracy: 0.6267 - val_loss: 1.6965
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 533ms/step - accuracy: 1.0000 - loss: 0.6717 - val_accuracy: 0.0414 - val_loss: 10.1410
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 538ms/step - accuracy: 0.9990 - loss: 0.6550 - val_accuracy: 0.0626 - val_loss: 4.6461
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 529ms/step - accuracy: 1.0000 - loss: 0.6461 - val_accuracy: 0.0429 - val_loss: 5.6053
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 539ms/step - accuracy: 1.0000 - loss: 0.6402 - val_accuracy: 0.0520 - val_loss: 5.2830
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 569ms/step - accuracy: 1.0000 - loss: 0.6383 - val_accuracy: 0.9963 - val_loss: 0.6475
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 533ms/step - accuracy: 1.0000 - loss: 0.6375 - val_accuracy: 0.9958 - val_loss: 0.6644
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 546ms/step - accuracy: 1.0000 - loss: 0.6364 - val_accuracy: 0.8563 - val_loss: 1.2423
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 531ms/step - accuracy: 1.0000 - loss: 0.6361 - val_accuracy: 0.0567 - val_loss: 4.7175
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 541ms/step - accuracy: 1.0000 - loss: 0.6355 - val_accuracy: 0.9963 - val_loss: 0.6542
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 559ms/step - accuracy: 1.0000 - loss: 0.6346 - val_accuracy: 0.0414 - val_loss: 8.5243
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 530ms/step - accuracy: 1.0000 - loss: 0.6347 - val_accuracy: 0.9963 - val_loss: 0.6443
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 540ms/step - accuracy: 1.0000 - loss: 0.6335 - val_accuracy: 0.9062 - val_loss: 1.0832
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 538ms/step - accuracy: 1.0000 - loss: 0.6349 - val_accuracy: 0.0461 - val_loss: 4.4720
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 546ms/step - accuracy: 1.0000 - loss: 0.6387 - val_accuracy: 0.0456 - val_loss: 4.7214
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 538ms/step - accuracy: 1.0000 - loss: 0.6372 - val_accuracy: 0.0525 - val_loss: 4.5550
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 539ms/step - accuracy: 1.0000 - loss: 0.6366 - val_accuracy: 0.0398 - val_loss: 4.8643
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 543ms/step - accuracy: 1.0000 - loss: 0.6390 - val_accuracy: 0.0414 - val_loss: 8.0759
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 535ms/step - accuracy: 0.9939 - loss: 0.6611 - val_accuracy: 0.0536 - val_loss: 107.5584
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 541ms/step - accuracy: 0.9150 - loss: 0.9709 - val_accuracy: 0.0536 - val_loss: 125.6809
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 304ms/step - accuracy: 0.9976 - loss: 0.6445
# Validation accuracy: 99.63%

# %% [markdown]
# # Save Model

# %%
mobilevit_xxs.save('/content/drive/MyDrive/PDM/model_ujicoba.keras')  # Change path as needed

# %%
# Serialize the model as a SavedModel.
tf.saved_model.save(mobilevit_xxs, "mobilevit_xxs")

# Convert to TFLite. This form of quantization is called
# post-training dynamic-range quantization in TFLite.
converter = tf.lite.TFLiteConverter.from_saved_model("mobilevit_xxs")
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,  # Enable TensorFlow Lite ops.
    tf.lite.OpsSet.SELECT_TF_OPS,  # Enable TensorFlow ops.
]
tflite_model = converter.convert()
open("mobilevit_xxs.tflite", "wb").write(tflite_model)
# Out:
# 306464
